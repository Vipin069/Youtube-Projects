# %%
import requests
import duckdb

# Define your video IDs
video_ids = ['Mdn0Nt-L4Zw', # Samsung galaxy S24 ultra
            'QCzxrjs3TPw', # Iphone 15 pro max
            'l7hPX1ne_Og', # Realme 12 pro
            '1T_qtOWVZqo', # Oneplus 12
            'w7WScSJSU9M'] # Redmi K70 pro

# YouTube API endpoint and parameters
api_key = 'AIzaSyAhsYfPiwHsy3FnLU-Ov1SSuMdW0q1fbQY'
api_url_base = 'https://www.googleapis.com/youtube/v3/videos'
params = {
    'part': 'snippet,contentDetails,statistics',
    'key': api_key
}

# Connect to DuckDB
conn = duckdb.connect(database='YTP.db')
c = conn.cursor()

# Create table if not exists
c.execute('CREATE TABLE IF NOT EXISTS video_data (video_id VARCHAR, title VARCHAR, views INT, likes INT, comments INT)')

# Loop through each video ID
for video_id in video_ids:
    # Make API request
    params['id'] = video_id
    response = requests.get(api_url_base, params=params)
    data = response.json()

    # Extract relevant data
    if 'items' in data:
        item = data['items'][0]
        snippet = item['snippet']
        statistics = item['statistics']

        # Insert data into table
        c.execute('INSERT INTO video_data VALUES (?, ?, ?, ?, ?)', (video_id, snippet['title'], int(statistics.get('viewCount', 0)), int(statistics.get('likeCount', 0)), int(statistics.get('commentCount', 0))))
    else:
        print(f"No data found for video ID: {video_id}")

# Commit changes and close connection
conn.commit()
conn.close()

# %%
import duckdb

# Connect to the database
conn = duckdb.connect(database='YTP.db')
c = conn.cursor()

# Execute your query
c.execute('SELECT * FROM video_data')

# Fetch and print the result
result = c.fetchall()
print(result)

# Close the connection
conn.close()
# Out:
# [('Mdn0Nt-L4Zw', 'Samsung Galaxy S24 Ultra Unboxing & First Look - The First AI Smartphone Is Here🔥🔥🔥', 1002550, 32814, 1746), ('QCzxrjs3TPw', 'Apple iPhone 15 Pro Max Unboxing & First Look - The Best Pro In Town🔥🔥🔥', 2906227, 104533, 6040), ('l7hPX1ne_Og', 'Realme 12 Pro+ Unboxing & First Look - Best Portrait Master?🔥🔥🔥', 305147, 13352, 804), ('1T_qtOWVZqo', 'OnePlus 12 Unboxing & First Look - The Ultimate Flagship Experience🔥🔥🔥', 338249, 14000, 840), ('w7WScSJSU9M', 'Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥', 247592, 10535, 533), ('Mdn0Nt-L4Zw', 'Samsung Galaxy S24 Ultra Unboxing & First Look - The First AI Smartphone Is Here🔥🔥🔥', 1007436, 32919, 1752), ('QCzxrjs3TPw', 'Apple iPhone 15 Pro Max Unboxing & First Look - The Best Pro In Town🔥🔥🔥', 2907792, 104581, 6042), ('l7hPX1ne_Og', 'Realme 12 Pro+ Unboxing & First Look - Best Portrait Master?🔥🔥🔥', 307397, 13415, 804), ('1T_qtOWVZqo', 'OnePlus 12 Unboxing & First Look - The Ultimate Flagship Experience🔥🔥🔥', 339742, 14036, 841), 
# ...

# %%
import pandas as pd
df = pd.DataFrame(result)
print(df)
# Out:
#               0                                                  1        2  \
# 0   Mdn0Nt-L4Zw  Samsung Galaxy S24 Ultra Unboxing & First Look...  1002550
# 1   QCzxrjs3TPw  Apple iPhone 15 Pro Max Unboxing & First Look ...  2906227
# 2   l7hPX1ne_Og  Realme 12 Pro+ Unboxing & First Look - Best Po...   305147
# 3   1T_qtOWVZqo  OnePlus 12 Unboxing & First Look - The Ultimat...   338249
# 4   w7WScSJSU9M       Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥   247592
# 5   Mdn0Nt-L4Zw  Samsung Galaxy S24 Ultra Unboxing & First Look...  1007436
# 6   QCzxrjs3TPw  Apple iPhone 15 Pro Max Unboxing & First Look ...  2907792
# 7   l7hPX1ne_Og  Realme 12 Pro+ Unboxing & First Look - Best Po...   307397
# 8   1T_qtOWVZqo  OnePlus 12 Unboxing & First Look - The Ultimat...   339742
# 9   w7WScSJSU9M       Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥   248524
# 10  Mdn0Nt-L4Zw  Samsung Galaxy S24 Ultra Unboxing & First Look...  1012541
# ...

# %%
# df.to_csv('YTA.csv')

# %%
import pandas as pd
df1 = pd.read_csv('YTA.csv')
df1
# Out:
#     Unnamed: 0            0  \
# 0            0  Mdn0Nt-L4Zw
# 1            1  QCzxrjs3TPw
# 2            2  l7hPX1ne_Og
# 3            3  1T_qtOWVZqo
# 4            4  w7WScSJSU9M
# 5            5  Mdn0Nt-L4Zw
# 6            6  QCzxrjs3TPw
# 7            7  l7hPX1ne_Og
# 8            8  1T_qtOWVZqo
# 9            9  w7WScSJSU9M
# 10          10  Mdn0Nt-L4Zw
# 11          11  QCzxrjs3TPw
# 12          12  l7hPX1ne_Og
# 13          13  1T_qtOWVZqo
# 14          14  w7WScSJSU9M
#
#                                                     1        2       3     4
# 0   Samsung Galaxy S24 Ultra Unboxing & First Look...  1002550   32814  1746
# 1   Apple iPhone 15 Pro Max Unboxing & First Look ...  2906227  104533  6040
# 2   Realme 12 Pro+ Unboxing & First Look - Best Po...   305147   13352   804
# 3   OnePlus 12 Unboxing & First Look - The Ultimat...   338249   14000   840
# 4        Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥   247592   10535   533
# ...

# %%
df1 = df1.drop('Unnamed: 0',axis=1)
df1
# Out:
#               0                                                  1        2  \
# 0   Mdn0Nt-L4Zw  Samsung Galaxy S24 Ultra Unboxing & First Look...  1002550
# 1   QCzxrjs3TPw  Apple iPhone 15 Pro Max Unboxing & First Look ...  2906227
# 2   l7hPX1ne_Og  Realme 12 Pro+ Unboxing & First Look - Best Po...   305147
# 3   1T_qtOWVZqo  OnePlus 12 Unboxing & First Look - The Ultimat...   338249
# 4   w7WScSJSU9M       Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥   247592
# 5   Mdn0Nt-L4Zw  Samsung Galaxy S24 Ultra Unboxing & First Look...  1007436
# 6   QCzxrjs3TPw  Apple iPhone 15 Pro Max Unboxing & First Look ...  2907792
# 7   l7hPX1ne_Og  Realme 12 Pro+ Unboxing & First Look - Best Po...   307397
# 8   1T_qtOWVZqo  OnePlus 12 Unboxing & First Look - The Ultimat...   339742
# 9   w7WScSJSU9M       Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥   248524
# 10  Mdn0Nt-L4Zw  Samsung Galaxy S24 Ultra Unboxing & First Look...  1012541
# ...

# %%
df1 = df1.drop('0',axis=1)
df1
# Out:
#                                                     1        2       3     4
# 0   Samsung Galaxy S24 Ultra Unboxing & First Look...  1002550   32814  1746
# 1   Apple iPhone 15 Pro Max Unboxing & First Look ...  2906227  104533  6040
# 2   Realme 12 Pro+ Unboxing & First Look - Best Po...   305147   13352   804
# 3   OnePlus 12 Unboxing & First Look - The Ultimat...   338249   14000   840
# 4        Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥   247592   10535   533
# 5   Samsung Galaxy S24 Ultra Unboxing & First Look...  1007436   32919  1752
# 6   Apple iPhone 15 Pro Max Unboxing & First Look ...  2907792  104581  6042
# 7   Realme 12 Pro+ Unboxing & First Look - Best Po...   307397   13415   804
# 8   OnePlus 12 Unboxing & First Look - The Ultimat...   339742   14036   841
# 9        Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥   248524   10560   533
# 10  Samsung Galaxy S24 Ultra Unboxing & First Look...  1012541   33009  1756
# ...

# %%
df1 = df1.rename(columns={'1': 'Title', '2': 'ViewCount', '3': 'LikeCount','4':'CommentCount'})
df1
# Out:
#                                                 Title  ViewCount  LikeCount  \
# 0   Samsung Galaxy S24 Ultra Unboxing & First Look...    1002550      32814
# 1   Apple iPhone 15 Pro Max Unboxing & First Look ...    2906227     104533
# 2   Realme 12 Pro+ Unboxing & First Look - Best Po...     305147      13352
# 3   OnePlus 12 Unboxing & First Look - The Ultimat...     338249      14000
# 4        Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥     247592      10535
# 5   Samsung Galaxy S24 Ultra Unboxing & First Look...    1007436      32919
# 6   Apple iPhone 15 Pro Max Unboxing & First Look ...    2907792     104581
# 7   Realme 12 Pro+ Unboxing & First Look - Best Po...     307397      13415
# 8   OnePlus 12 Unboxing & First Look - The Ultimat...     339742      14036
# 9        Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥     248524      10560
# 10  Samsung Galaxy S24 Ultra Unboxing & First Look...    1012541      33009
# ...

# %%
df1=df1.drop(5)
df1=df1.drop(6)
df1=df1.drop(7)
df1=df1.drop(8)
df1=df1.drop(9)
df1=df1.drop(10)
df1=df1.drop(11)
df1=df1.drop(12)
df1=df1.drop(13)
df1=df1.drop(14)

# %%
df1
# Out:
#                                                Title  ViewCount  LikeCount  \
# 0  Samsung Galaxy S24 Ultra Unboxing & First Look...    1002550      32814
# 1  Apple iPhone 15 Pro Max Unboxing & First Look ...    2906227     104533
# 2  Realme 12 Pro+ Unboxing & First Look - Best Po...     305147      13352
# 3  OnePlus 12 Unboxing & First Look - The Ultimat...     338249      14000
# 4       Redmi K70 Pro Unboxing - Budget Flagship?🔥🔥🔥     247592      10535
#
#    CommentCount
# 0          1746
# 1          6040
# 2           804
# 3           840
# 4           533

# %%
df1['ViewCount'] = pd.to_numeric(df1['ViewCount'])
df1['LikeCount'] = pd.to_numeric(df1['LikeCount'])
df1['CommentCount'] = pd.to_numeric(df1['CommentCount'])
df1.dtypes
# Out:
# Title           object
# ViewCount        int64
# LikeCount        int64
# CommentCount     int64
# dtype: object

# %%
import pandas as pd
import plotly.express as px
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output


# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the dashboard
app.layout = html.Div([
    html.H1("YouTube Channels Dashboard"),
    html.Label("Select a metric:"),
    dcc.Dropdown(
        id='metric-dropdown',
        options=[
            {'label': 'CommentCount', 'value': 'CommentCount'},
            {'label': 'LikeCount', 'value': 'LikeCount'},
            {'label': 'ViewCount', 'value': 'ViewCount'}
        ],
        value='Subscribers'
    ),
    dcc.Graph(id='channel-bar-chart'),
    dcc.Graph(id='channel-bar2-chart'),
    dcc.Graph(id='channel-pie-chart'),
    dcc.Graph(id='channel-scatter-chart')
])

# Define callback to update the bar chart based on dropdown selection
@app.callback(
    Output('channel-bar-chart', 'figure'),
    [Input('metric-dropdown', 'value')]
)
def update_bar_chart(selected_metric):
    fig = px.bar(df1, x='CommentCount', y='Title', title='Total Comment Counts',orientation='h')
    return fig

# Define callback to update the line chart based on dropdown selection
@app.callback(
    Output('channel-bar2-chart', 'figure'),
    [Input('metric-dropdown', 'value')]
)
def update_bar_chart(selected_metric):
    fig = px.bar(df1, x='LikeCount', y='Title', title='Total Likes Counts',orientation='h')
    return fig
# Define callback to update the pie chart based on dropdown selection
@app.callback(
    Output('channel-pie-chart', 'figure'),
    [Input('metric-dropdown', 'value')]
)
def update_pie_chart(selected_metric):
    fig = px.pie(df1, values='ViewCount', names='Title', title='Total View Counts')
    return fig

@app.callback(
    Output('channel-scatter-chart', 'figure'),
    [Input('metric-dropdown', 'value')]
)
def update_scatter_chart(selected_metric):
    fig = px.scatter(df1, x='ViewCount', y='LikeCount', title='Relation Between Views and Likes')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# /var/folders/nv/tbsb_l812gjbq2nx_7_wdl_m0000gn/T/ipykernel_62577/1203393970.py:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# /var/folders/nv/tbsb_l812gjbq2nx_7_wdl_m0000gn/T/ipykernel_62577/1203393970.py:5: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
